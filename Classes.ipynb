# %% [markdown]
# <a href="https://colab.research.google.com/github/is23631/Python-Learning/blob/main/Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Employee():

  emp_name="RAJ"
  emp_dept="IT"

  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept}")

emp1=Employee()
emp1.info()
emp1.emp_name
# Out:
# Employee RAJ works for IT
# 'RAJ'

# %%
my_list=[100,200,300,400]

for i,x in enumerate(my_list):
  print("The index positions of the list",i)

  print("The value of the list",x)
# Out:
# The index positions of the list 0
# The value of the list 100
# The index positions of the list 1
# The value of the list 200
# The index positions of the list 2
# The value of the list 300
# The index positions of the list 3
# The value of the list 400
