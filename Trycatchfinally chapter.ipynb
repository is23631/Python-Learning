# %% [markdown]
# <a href="https://colab.research.google.com/github/is23631/Python-Learning/blob/main/Trycatchfinally%20chapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="10"

try:
  if (x>10):
    print("x is greater than 10")
  else:
    print("x is less than 10")
except Exception as e:
  print(f"This is the error: {e}")
finally:
  print("Hello World")
# Out:
# This is the error: '>' not supported between instances of 'str' and 'int'
# Hello World
